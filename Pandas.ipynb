# %%
# pip install pandas

# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\Neha\\Downloads\\sales_customer_analytics.csv")

# %%
df.head(10) #head() is used to view the first five rows along with each and every column in the dataset
# Out:
#    OrderID   OrderDate  CustomerID CustomerName       City     Product  \
# 0     1001  2024-01-01         252        Pooja      Delhi      Laptop
# 1     1002  2024-01-01         293    Siddharth     Mumbai      Mobile
# 2     1003  2024-01-01         215        Megha  Hyderabad      Mobile
# 3     1004  2024-01-01         272       Ananya  Hyderabad     Monitor
# 4     1005  2024-01-02         261        Rohit    Chennai      Tablet
# 5     1006  2024-01-02         221    Siddharth       Pune      Laptop
# 6     1007  2024-01-02         283         Riya  Bangalore        Desk
# 7     1008  2024-01-03         287        Kavya      Delhi        Desk
# 8     1009  2024-01-03         275         Riya  Hyderabad    Keyboard
# 9     1010  2024-01-03         275         Isha     Mumbai  Headphones
#
#       Category  Quantity  UnitPrice  DiscountPct  PaymentMode OrderStatus  \
# 0  Electronics         1       5852         0.10          UPI    Returned
# ...

# %%
df.tail(10) #tail() is used to view the last 5 rows (default) along with each and every column in the dataset
# Out:
#      OrderID   OrderDate  CustomerID CustomerName       City     Product  \
# 540     1541  2024-06-27         280        Sneha    Chennai        Desk
# 541     1542  2024-06-27         202        Rahul  Bangalore      Mobile
# 542     1543  2024-06-27         292        Karan     Mumbai      Tablet
# 543     1544  2024-06-28         232        Megha       Pune       Chair
# 544     1545  2024-06-28         291       Aditya    Chennai       Mouse
# 545     1546  2024-06-28         284         Neha      Delhi     Monitor
# 546     1547  2024-06-29         224        Pooja      Delhi        Desk
# 547     1548  2024-06-29         212        Megha     Mumbai        Desk
# 548     1549  2024-06-29         250       Manish    Chennai  Headphones
# 549     1550  2024-06-30         235        Megha     Mumbai     Monitor
#
#         Category  Quantity  UnitPrice  DiscountPct  PaymentMode OrderStatus  \
# 540    Furniture         2      23353         0.20   Debit Card   Delivered
# ...

# %%
df.info() # info() is used to check for information of the dataframe columns.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderID       550 non-null    int64
#  1   OrderDate     550 non-null    object
#  2   CustomerID    550 non-null    int64
#  3   CustomerName  550 non-null    object
#  4   City          550 non-null    object
#  5   Product       550 non-null    object
#  6   Category      550 non-null    object
#  7   Quantity      550 non-null    int64
#  8   UnitPrice     550 non-null    int64
#  9   DiscountPct   458 non-null    float64
#  10  PaymentMode   550 non-null    object
#  11  OrderStatus   550 non-null    object
#  12  Rating        512 non-null    float64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 56.0+ KB

# %%
df.describe() # describe() returns the statistical summary only for numerical columns
# Out:
#            OrderID  CustomerID    Quantity     UnitPrice  DiscountPct  \
# count   550.000000  550.000000  550.000000    550.000000   458.000000
# mean   1275.500000  250.258182    2.454545  33071.741818     0.099891
# std     158.915596   29.763651    1.108309  18322.527529     0.069894
# min    1001.000000  201.000000    1.000000   1007.000000     0.000000
# 25%    1138.250000  224.000000    1.000000  17455.750000     0.050000
# 50%    1275.500000  251.000000    2.000000  33185.000000     0.100000
# 75%    1412.750000  275.000000    3.000000  49023.500000     0.150000
# max    1550.000000  300.000000    4.000000  64910.000000     0.200000
#
#            Rating
# count  512.000000
# mean     3.742188
# std      1.139891
# min      1.000000
# 25%      3.000000
# 50%      4.000000
# 75%      5.000000
# max      5.000000

# %% [markdown]
# -OrderId
# -orderid feature have **550** values.
# -orderid feature mean value **1275.500000** is greater than standard deviation value **158.915596** ,less data variated
# -orderid feature **1001** is the minimum value and 1550 is the maximum value in this column.
# -orderid 25% of data is below this **1138**
# -orderid 50% of data is below this **1275**
# -orderid 75% of data is below this **1412**

# %% [markdown]
# -OrderDate
# -orderdate feature have **550** values
# -orderdate feature have **182** unique values
# -orderdate **01-01-2024** is the most frequent value in this column ,because it is repeated 4 times.

# %% [markdown]
# -CustomerId
# -customerid have **550** values
# -customerid  mean value **250.258182** is more than mean value **29.763651**so the data is less variated.
# -customerid  **201** is the minimum value and **300** is the maximum value.
# -customerid 25% of data is below this **224**
# -customerid 50% of data is below this **251**
# -customerid 75% of data is below this **271**

# %% [markdown]
# -CustomerName
# -customername feature have **550** values
# -ocustomername feature have **20** unique values
# -customername feature **pooja** is the most frequent value in this column ,because it is repeated **37** times.

# %% [markdown]
# -City
# -city feature have **550** values.
# -city feature have **6** unique values
# -city feature **chennai** is the most frequent value in this column ,because it is repeated **102** times.

# %% [markdown]
# -Product
# -product feature have **550** values
# -poduct feature have **9** unique values
# -product feature **chair** is the most frequent value in this column ,because it is repeated **68** times.

# %% [markdown]
# -Category
# -category feature have **550** values
# -category feature have **3** unique values
# -category feature **electronics** is the most frequent value in this column ,because it is repeated **243** times.

# %% [markdown]
# -Quantity
# -quantity feature have **550** values
# -quantity feature mean value **2.454545** is more than standard deviation value **1.108309** so the data is less variated.
# -quantityid 25% of data is below this **1**
# -quantityid 50% of data is below this **2**
# -quantityid 75% of data is below this **3**

# %% [markdown]
# -UnitPrice
# -unitprice feature have **550** values
# -unitprice feature mean value **33071.741818** is more than standard deviation value **18322.527529** so the data is less variated.
# -unitprice feature **1007** is the minimum value and maximum value **64910**
# -unitprice 25% of data is below this **17455.750000**
# -unitprice 50% of data is below this **33185**
# -unitprice 75% of data is below this **49023.500000**

# %% [markdown]
# - DiscountPct
# -discountpct feature have **550** values
# -discountpct feature both the values standard deviation and mean are same or zero
# -discountpct feature **0** is the minimum value and maximum value **0**  of this column.
# -discountpct 25% of data is below this **0**
# -discountpct 50% of data is below this **0**
# -discountpct 75% of data is below this **0**

# %% [markdown]
# -PaymentMode
# -paymentmode feature have **550** values
# -paymentmode feature have **4** unique values
# -paymentmode feature **upi** is the most frequent value in this column ,because it is repeated **156** times.

# %% [markdown]
# -OrderStatus
# -orderstatus feature have **550** values
# -orderstatus feature have **3** unique values.
# -orderstatus feature **delivered** is the most frequent value in this column,because it is repeated **457** times.

# %% [markdown]
# -Rating
# -rating feature have **550** values
# -rating have mean **3** is greater than standard deviation **1** so the data is less varited.
# -rating feature **1** is the minimum value  and maximum value **5**of this column.
# -rating 25% of data lies below this **3**
# -rating 50% of data lies below this **4**
# -rating 75% of data lies below this **5**

# %% [markdown]
# -TotalSale
# -totalsale feature have **550** values
# -totalsale feature have mean **81438.976364** is greater than standard deviation **63585.253514** so the data is less varited.
# -totalsale feature **1136** is the minimum value and maximum value **259640** of this column.
# -totalsale 25% of data lies below this **32630**
# -totalsale 50% of data lies below this  **61669**
# -totalsale 75% of data lies below this **115376.750000**

# %% [markdown]
# -ExactSalesAmount
# -exactsalesamount feature have **550** values
# -exactsalesamount feature have mean **74457** is greater than standard deviation **58421** so the data is less varited.
# -exactsalesamount **1136** is the minimum value and maximum value **244372** of this column.
# -exactsalesamount 25% of data lies below this **29283.487500**
# -exactsalesamount  50% of data lies below this **54992.200000**
# -exactsalesamount 75% of data lies below this **106387**

# %%
df.describe(include="all") # describe(include="all") return the statistical summary for all the columns.
# Out:
#             OrderID   OrderDate  CustomerID CustomerName     City Product  \
# count    550.000000         550  550.000000          550      550     550
# unique          NaN         182         NaN           20        6       9
# top             NaN  2024-01-01         NaN        Pooja  Chennai   Chair
# freq            NaN           4         NaN           37      102      68
# mean    1275.500000         NaN  250.258182          NaN      NaN     NaN
# std      158.915596         NaN   29.763651          NaN      NaN     NaN
# min     1001.000000         NaN  201.000000          NaN      NaN     NaN
# 25%     1138.250000         NaN  224.000000          NaN      NaN     NaN
# 50%     1275.500000         NaN  251.000000          NaN      NaN     NaN
# 75%     1412.750000         NaN  275.000000          NaN      NaN     NaN
# max     1550.000000         NaN  300.000000          NaN      NaN     NaN
#
#            Category    Quantity     UnitPrice  DiscountPct PaymentMode  \
# ...

# %%
df.isna().sum() # isna().sum() is used to get the total count of missing values in each and every column
# Out:
# OrderID          0
# OrderDate        0
# CustomerID       0
# CustomerName     0
# City             0
# Product          0
# Category         0
# Quantity         0
# UnitPrice        0
# DiscountPct     92
# PaymentMode      0
# OrderStatus      0
# Rating          38
# dtype: int64

# %%
df.duplicated().sum() # duplicated().sum() is used to get the count of duplicate rows
# Out:
# np.int64(0)

# %%
df["DiscountPct"]= df["DiscountPct"].fillna(0)

# %%
df["Rating"].fillna(df["Rating"].mean(),inplace=True)
# Out:
# C:\Users\Neha\AppData\Local\Temp\ipykernel_7872\322049203.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Rating"].fillna(df["Rating"].mean(),inplace=True)

# %%
df.isna().sum()
# Out:
# OrderID         0
# OrderDate       0
# CustomerID      0
# CustomerName    0
# City            0
# Product         0
# Category        0
# Quantity        0
# UnitPrice       0
# DiscountPct     0
# PaymentMode     0
# OrderStatus     0
# Rating          0
# dtype: int64

# %%
df.dtypes
# Out:
# OrderID           int64
# OrderDate        object
# CustomerID        int64
# CustomerName     object
# City             object
# Product          object
# Category         object
# Quantity          int64
# UnitPrice         int64
# DiscountPct     float64
# PaymentMode      object
# OrderStatus      object
# Rating          float64
# dtype: object

# %%
df['OrderDate']=pd.to_datetime(df['OrderDate'])

# %%
df.dtypes
# Out:
# OrderID                  int64
# OrderDate       datetime64[ns]
# CustomerID               int64
# CustomerName            object
# City                    object
# Product                 object
# Category                object
# Quantity                 int64
# UnitPrice                int64
# DiscountPct            float64
# PaymentMode             object
# OrderStatus             object
# Rating                 float64
# dtype: object

# %%
df['TotalSale']=df["Quantity"]*df["UnitPrice"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderID       550 non-null    int64
#  1   OrderDate     550 non-null    datetime64[ns]
#  2   CustomerID    550 non-null    int64
#  3   CustomerName  550 non-null    object
#  4   City          550 non-null    object
#  5   Product       550 non-null    object
#  6   Category      550 non-null    object
#  7   Quantity      550 non-null    int64
#  8   UnitPrice     550 non-null    int64
#  9   DiscountPct   550 non-null    float64
#  10  PaymentMode   550 non-null    object
#  11  OrderStatus   550 non-null    object
#  12  Rating        550 non-null    float64
#  13  TotalSale     550 non-null    int64
# dtypes: datetime64[ns](1), float64(2), int64(5), object(6)
# memory usage: 60.3+ KB

# %%
df.head()
# Out:
#    OrderID  OrderDate  CustomerID CustomerName       City  Product  \
# 0     1001 2024-01-01         252        Pooja      Delhi   Laptop
# 1     1002 2024-01-01         293    Siddharth     Mumbai   Mobile
# 2     1003 2024-01-01         215        Megha  Hyderabad   Mobile
# 3     1004 2024-01-01         272       Ananya  Hyderabad  Monitor
# 4     1005 2024-01-02         261        Rohit    Chennai   Tablet
#
#       Category  Quantity  UnitPrice  DiscountPct PaymentMode OrderStatus  \
# 0  Electronics         1       5852         0.10         UPI    Returned
# 1  Electronics         1      27922         0.05        Cash   Delivered
# 2  Electronics         3      42376         0.15  Debit Card   Cancelled
# 3  Electronics         1      61492         0.20         UPI   Delivered
# 4  Electronics         1      18306         0.15        Cash   Cancelled
#
#    Rating  TotalSale
# 0     5.0       5852
# 1     5.0      27922
# 2     5.0     127128
# 3     3.0      61492
# ...

# %%
df['ExactSalesAmount']=df['TotalSale']*(1-df['DiscountPct'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   OrderID           550 non-null    int64
#  1   OrderDate         550 non-null    datetime64[ns]
#  2   CustomerID        550 non-null    int64
#  3   CustomerName      550 non-null    object
#  4   City              550 non-null    object
#  5   Product           550 non-null    object
#  6   Category          550 non-null    object
#  7   Quantity          550 non-null    int64
#  8   UnitPrice         550 non-null    int64
#  9   DiscountPct       550 non-null    float64
#  10  PaymentMode       550 non-null    object
#  11  OrderStatus       550 non-null    object
#  12  Rating            550 non-null    float64
#  13  TotalSale         550 non-null    int64
#  14  ExactSalesAmount  550 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int64(5), object(6)
# ...

# %%
# fetching columns single
df["CustomerName"]
# Out:
# 0          Pooja
# 1      Siddharth
# 2          Megha
# 3         Ananya
# 4          Rohit
#          ...
# 545         Neha
# 546        Pooja
# 547        Megha
# 548       Manish
# 549        Megha
# Name: CustomerName, Length: 550, dtype: object

# %%
#multiple columns
df[["CustomerName","City","Product","Category"]]
# Out:
#     CustomerName       City     Product     Category
# 0          Pooja      Delhi      Laptop  Electronics
# 1      Siddharth     Mumbai      Mobile  Electronics
# 2          Megha  Hyderabad      Mobile  Electronics
# 3         Ananya  Hyderabad     Monitor  Electronics
# 4          Rohit    Chennai      Tablet  Electronics
# ..           ...        ...         ...          ...
# 545         Neha      Delhi     Monitor  Electronics
# 546        Pooja      Delhi        Desk    Furniture
# 547        Megha     Mumbai        Desk    Furniture
# 548       Manish    Chennai  Headphones  Accessories
# 549        Megha     Mumbai     Monitor  Electronics
#
# [550 rows x 4 columns]

# %%
# fetching rows based on indexes-same as python slicing
df[5:10]
# Out:
#    OrderID  OrderDate  CustomerID CustomerName       City     Product  \
# 5     1006 2024-01-02         221    Siddharth       Pune      Laptop
# 6     1007 2024-01-02         283         Riya  Bangalore        Desk
# 7     1008 2024-01-03         287        Kavya      Delhi        Desk
# 8     1009 2024-01-03         275         Riya  Hyderabad    Keyboard
# 9     1010 2024-01-03         275         Isha     Mumbai  Headphones
#
#       Category  Quantity  UnitPrice  DiscountPct  PaymentMode OrderStatus  \
# 5  Electronics         3       6444         0.00  Credit Card   Delivered
# 6    Furniture         2      54444         0.10          UPI   Cancelled
# 7    Furniture         3      59963         0.00  Credit Card   Delivered
# 8  Accessories         1      57218         0.15   Debit Card   Delivered
# 9  Accessories         1      25044         0.05          UPI   Delivered
#
#      Rating  TotalSale  ExactSalesAmount
# 5  3.000000      19332           19332.0
# ...

# %%
# boolean filtering
df[df["City"]=="Pune"]
# Out:
#      OrderID  OrderDate  CustomerID CustomerName  City   Product     Category  \
# 5       1006 2024-01-02         221    Siddharth  Pune    Laptop  Electronics
# 10      1011 2024-01-04         288        Pooja  Pune    Mobile  Electronics
# 12      1013 2024-01-04         224        Kavya  Pune    Tablet  Electronics
# 18      1019 2024-01-06         230       Aditya  Pune      Desk    Furniture
# 21      1022 2024-01-07         264    Siddharth  Pune  Keyboard  Accessories
# ..       ...        ...         ...          ...   ...       ...          ...
# 526     1527 2024-06-22         269         Riya  Pune    Mobile  Electronics
# 532     1533 2024-06-24         219       Manish  Pune  Keyboard  Accessories
# 536     1537 2024-06-25         269       Aditya  Pune    Laptop  Electronics
# 537     1538 2024-06-26         204        Rahul  Pune     Chair    Furniture
# 543     1544 2024-06-28         232        Megha  Pune     Chair    Furniture
#
# ...

# %%
df[df["OrderStatus"]=="Delivered"]
# Out:
#      OrderID  OrderDate  CustomerID CustomerName       City   Product  \
# 1       1002 2024-01-01         293    Siddharth     Mumbai    Mobile
# 3       1004 2024-01-01         272       Ananya  Hyderabad   Monitor
# 5       1006 2024-01-02         221    Siddharth       Pune    Laptop
# 7       1008 2024-01-03         287        Kavya      Delhi      Desk
# 8       1009 2024-01-03         275         Riya  Hyderabad  Keyboard
# ..       ...        ...         ...          ...        ...       ...
# 544     1545 2024-06-28         291       Aditya    Chennai     Mouse
# 545     1546 2024-06-28         284         Neha      Delhi   Monitor
# 546     1547 2024-06-29         224        Pooja      Delhi      Desk
# 547     1548 2024-06-29         212        Megha     Mumbai      Desk
# 549     1550 2024-06-30         235        Megha     Mumbai   Monitor
#
#         Category  Quantity  UnitPrice  DiscountPct  PaymentMode OrderStatus  \
# ...

# %%
# Multiple Conditions
df[(df["City"]=="Pune") & (df["OrderStatus"]=="Delivered")]
# Out:
#      OrderID  OrderDate  CustomerID CustomerName  City   Product     Category  \
# 5       1006 2024-01-02         221    Siddharth  Pune    Laptop  Electronics
# 10      1011 2024-01-04         288        Pooja  Pune    Mobile  Electronics
# 18      1019 2024-01-06         230       Aditya  Pune      Desk    Furniture
# 21      1022 2024-01-07         264    Siddharth  Pune  Keyboard  Accessories
# 22      1023 2024-01-08         260       Manish  Pune    Tablet  Electronics
# ..       ...        ...         ...          ...   ...       ...          ...
# 526     1527 2024-06-22         269         Riya  Pune    Mobile  Electronics
# 532     1533 2024-06-24         219       Manish  Pune  Keyboard  Accessories
# 536     1537 2024-06-25         269       Aditya  Pune    Laptop  Electronics
# 537     1538 2024-06-26         204        Rahul  Pune     Chair    Furniture
# 543     1544 2024-06-28         232        Megha  Pune     Chair    Furniture
#
# ...

# %%
# using isin we can check multiple filters
df[df["City"].isin(["Pune","Chennai"])]
# Out:
#      OrderID  OrderDate  CustomerID CustomerName     City     Product  \
# 4       1005 2024-01-02         261        Rohit  Chennai      Tablet
# 5       1006 2024-01-02         221    Siddharth     Pune      Laptop
# 10      1011 2024-01-04         288        Pooja     Pune      Mobile
# 12      1013 2024-01-04         224        Kavya     Pune      Tablet
# 13      1014 2024-01-05         203        Pooja  Chennai     Monitor
# ..       ...        ...         ...          ...      ...         ...
# 539     1540 2024-06-26         224       Manish  Chennai      Laptop
# 540     1541 2024-06-27         280        Sneha  Chennai        Desk
# 543     1544 2024-06-28         232        Megha     Pune       Chair
# 544     1545 2024-06-28         291       Aditya  Chennai       Mouse
# 548     1549 2024-06-29         250       Manish  Chennai  Headphones
#
#         Category  Quantity  UnitPrice  DiscountPct  PaymentMode OrderStatus  \
# ...

# %%
df[df["TotalSale"].between(5000,15000)] #use between for range filter
# Out:
#      OrderID  OrderDate  CustomerID CustomerName       City     Product  \
# 0       1001 2024-01-01         252        Pooja      Delhi      Laptop
# 18      1019 2024-01-06         230       Aditya       Pune        Desk
# 21      1022 2024-01-07         264    Siddharth       Pune    Keyboard
# 58      1059 2024-01-20         202        Priya    Chennai     Monitor
# 94      1095 2024-01-31         240        Kunal      Delhi      Tablet
# 102     1103 2024-02-03         260        Rohit    Chennai  Headphones
# 110     1111 2024-02-06         209        Rahul    Chennai     Monitor
# 145     1146 2024-02-17         203    Siddharth      Delhi      Mobile
# 161     1162 2024-02-23         296        Pooja       Pune        Desk
# 168     1169 2024-02-25         236        Priya     Mumbai     Monitor
# 188     1189 2024-03-02         292    Siddharth      Delhi     Monitor
# 193     1194 2024-03-04         227        Aarav      Delhi    Keyboard
# ...

# %%
df.sort_values("TotalSale")# sorting values default is ascending
# Out:
#      OrderID  OrderDate  CustomerID CustomerName       City     Product  \
# 507     1508 2024-06-16         278        Aarav  Hyderabad     Monitor
# 330     1331 2024-04-18         221        Pooja  Bangalore       Mouse
# 107     1108 2024-02-05         265        Rahul  Hyderabad      Tablet
# 294     1295 2024-04-06         237         Riya      Delhi      Laptop
# 198     1199 2024-03-06         272       Nikita  Bangalore        Desk
# ..       ...        ...         ...          ...        ...         ...
# 464     1465 2024-06-01         299        Rahul      Delhi       Mouse
# 420     1421 2024-05-18         257         Neha    Chennai       Mouse
# 40      1041 2024-01-14         262       Aditya    Chennai      Laptop
# 250     1251 2024-03-23         211       Aditya    Chennai     Monitor
# 366     1367 2024-04-30         244        Kunal       Pune  Headphones
#
#         Category  Quantity  UnitPrice  DiscountPct  PaymentMode OrderStatus  \
# ...

# %%
df.sort_values("TotalSale",ascending=False)
# Out:
#      OrderID  OrderDate  CustomerID CustomerName       City     Product  \
# 366     1367 2024-04-30         244        Kunal       Pune  Headphones
# 250     1251 2024-03-23         211       Aditya    Chennai     Monitor
# 40      1041 2024-01-14         262       Aditya    Chennai      Laptop
# 420     1421 2024-05-18         257         Neha    Chennai       Mouse
# 464     1465 2024-06-01         299        Rahul      Delhi       Mouse
# ..       ...        ...         ...          ...        ...         ...
# 198     1199 2024-03-06         272       Nikita  Bangalore        Desk
# 294     1295 2024-04-06         237         Riya      Delhi      Laptop
# 107     1108 2024-02-05         265        Rahul  Hyderabad      Tablet
# 330     1331 2024-04-18         221        Pooja  Bangalore       Mouse
# 507     1508 2024-06-16         278        Aarav  Hyderabad     Monitor
#
#         Category  Quantity  UnitPrice  DiscountPct  PaymentMode OrderStatus  \
# ...

# %%
df.sort_values(["City","TotalSale"],ascending=[True,False])
# Out:
#      OrderID  OrderDate  CustomerID CustomerName       City     Product  \
# 201     1202 2024-03-07         262        Sneha  Bangalore  Headphones
# 184     1185 2024-03-01         284        Aarav  Bangalore       Chair
# 405     1406 2024-05-13         233       Aditya  Bangalore  Headphones
# 528     1529 2024-06-23         234         Isha  Bangalore      Laptop
# 153     1154 2024-02-20         215        Kavya  Bangalore       Chair
# ..       ...        ...         ...          ...        ...         ...
# 497     1498 2024-06-12         222        Priya       Pune       Mouse
# 460     1461 2024-05-31         206       Aditya       Pune        Desk
# 21      1022 2024-01-07         264    Siddharth       Pune    Keyboard
# 413     1414 2024-05-16         299        Megha       Pune    Keyboard
# 356     1357 2024-04-27         297         Neha       Pune        Desk
#
#         Category  Quantity  UnitPrice  DiscountPct  PaymentMode OrderStatus  \
# ...

# %%
# Apply()-row-wise

def discount_label(x):
    if x==0:
        return "Nodiscount"
    elif x<=0.10:
        return "Low Discount"
    else:
        return "High Discount"
df["DiscountCategory"]=df["DiscountPct"].apply(discount_label)

# %%
df.head()
# Out:
#    OrderID  OrderDate  CustomerID CustomerName       City  Product  \
# 0     1001 2024-01-01         252        Pooja      Delhi   Laptop
# 1     1002 2024-01-01         293    Siddharth     Mumbai   Mobile
# 2     1003 2024-01-01         215        Megha  Hyderabad   Mobile
# 3     1004 2024-01-01         272       Ananya  Hyderabad  Monitor
# 4     1005 2024-01-02         261        Rohit    Chennai   Tablet
#
#       Category  Quantity  UnitPrice  DiscountPct PaymentMode OrderStatus  \
# 0  Electronics         1       5852         0.10         UPI    Returned
# 1  Electronics         1      27922         0.05        Cash   Delivered
# 2  Electronics         3      42376         0.15  Debit Card   Cancelled
# 3  Electronics         1      61492         0.20         UPI   Delivered
# 4  Electronics         1      18306         0.15        Cash   Cancelled
#
#    Rating  TotalSale  ExactSalesAmount DiscountCategory
# 0     5.0       5852            5266.8     Low Discount
# ...

# %%
# map()-maps the specified value to the given value

city_region={
    "Pune":"West",
    "Mumbai":"West",
    "Delhi":"North",
    "Banglore":"South",
    "Hyderabad":"South",
    "Chennai":"South"}
df["Region"]=df["City"].map(city_region)

# %%
df.head()
# Out:
#    OrderID  OrderDate  CustomerID CustomerName       City  Product  \
# 0     1001 2024-01-01         252        Pooja      Delhi   Laptop
# 1     1002 2024-01-01         293    Siddharth     Mumbai   Mobile
# 2     1003 2024-01-01         215        Megha  Hyderabad   Mobile
# 3     1004 2024-01-01         272       Ananya  Hyderabad  Monitor
# 4     1005 2024-01-02         261        Rohit    Chennai   Tablet
#
#       Category  Quantity  UnitPrice  DiscountPct PaymentMode OrderStatus  \
# 0  Electronics         1       5852         0.10         UPI    Returned
# 1  Electronics         1      27922         0.05        Cash   Delivered
# 2  Electronics         3      42376         0.15  Debit Card   Cancelled
# 3  Electronics         1      61492         0.20         UPI   Delivered
# 4  Electronics         1      18306         0.15        Cash   Cancelled
#
#    Rating  TotalSale  ExactSalesAmount DiscountCategory Region
# ...

# %%
df["City"].unique() # unique is used to get the unique value in the column.
# Out:
# array(['Delhi', 'Mumbai', 'Hyderabad', 'Chennai', 'Pune', 'Bangalore'],
#       dtype=object)

# %%
df["City"].nunique()# nunique is used to get the number of uinque value in the column.
# Out:
# 6

# %%
df["City"].value_counts() # value_count is used to get the total count for each unique value in the column.
# Out:
# City
# Chennai      102
# Pune          97
# Delhi         95
# Bangalore     93
# Mumbai        82
# Hyderabad     81
# Name: count, dtype: int64

# %% [markdown]
# # ASSIGNMENT

# %% [markdown]
# # 1.Load the dataset into a Pandas DataFrame.

# %%
df=pd.read_csv("C:\\Users\\Neha\\Downloads\\edtech_student_learning_data.csv")

# %% [markdown]
# # 2.Display the first 10 records of the dataset.

# %%
df.head(10)
# Out:
#    student_id student_name  gender       city enrollment_date          course  \
# 0        1001    Student_1    Male  Hyderabad      2024-11-25   Generative AI
# 1        1002    Student_2  Female  Hyderabad      2024-09-29         AI & ML
# 2        1003    Student_3    Male       Pune      2024-12-05    Data Science
# 3        1004    Student_4    Male      Delhi      2024-03-09         AI & ML
# 4        1005    Student_5    Male     Mumbai      2024-02-03   Generative AI
# 5        1006    Student_6  Female       Pune      2024-09-18   Generative AI
# 6        1007    Student_7    Male     Mumbai      2024-02-22  Data Analytics
# 7        1008    Student_8    Male    Chennai      2024-07-23    Data Science
# 8        1009    Student_9    Male     Mumbai      2024-05-05         AI & ML
# 9        1010   Student_10  Female      Delhi      2024-08-22  Data Analytics
#
#   batch_type  total_sessions  sessions_attended  avg_quiz_score  \
# ...

# %% [markdown]
# # 3.Display the last 5 records of the dataset.

# %%
df.tail()
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 500        1452  Student_452  Female     Mumbai      2024-03-07
# 501        1276  Student_276  Female  Hyderabad      2024-10-15
# 502        1210  Student_210    Male  Bangalore      2024-04-04
# 503        1178  Student_178    Male      Delhi      2024-01-20
# 504        1397  Student_397  Female     Mumbai      2024-05-27
#
#             course batch_type  total_sessions  sessions_attended  \
# 500  Generative AI    Weekday             120                 68
# 501  Generative AI    Weekday             120                 95
# 502        AI & ML    Weekday             120                 75
# 503  Generative AI    Weekday             120                 80
# 504  Generative AI    Weekend             120                101
#
#      avg_quiz_score  assignment_score  project_score  final_rating  \
# 500              84                84             58           2.2
# ...

# %% [markdown]
# # 4.Check the shape of the dataset.

# %% [markdown]
# # 5.Display all column names along with their data types.

# %%
df.dtypes
# Out:
# student_id             int64
# student_name          object
# gender                object
# city                  object
# enrollment_date       object
# course                object
# batch_type            object
# total_sessions         int64
# sessions_attended      int64
# avg_quiz_score         int64
# assignment_score       int64
# project_score          int64
# final_rating         float64
# learning_hours         int64
# placement_status      object
# feedback_score         int64
# attendance_pct       float64
# salary_offered       float64
# dtype: object

# %% [markdown]
# # 6.Generate summary statistics for all numerical columns.

# %%
df.describe()
# Out:
#         student_id  total_sessions  sessions_attended  avg_quiz_score  \
# count   505.000000           505.0         505.000000      505.000000
# mean   1251.015842           120.0          88.102970       69.601980
# std     144.242011             0.0          17.087232       17.137226
# min    1001.000000           120.0          60.000000       40.000000
# 25%    1127.000000           120.0          73.000000       56.000000
# 50%    1251.000000           120.0          88.000000       69.000000
# 75%    1376.000000           120.0         103.000000       84.000000
# max    1500.000000           120.0         119.000000       99.000000
#
#        assignment_score  project_score  final_rating  learning_hours  \
# count        505.000000     505.000000    505.000000      505.000000
# mean          71.984158      75.287129      3.535220       22.128713
# std           15.777337      14.678794      0.838068        9.924180
# ...

# %% [markdown]
# # Interpretations

# %% [markdown]
# -StudentId
# -studentid have **505** values.
# -In studentid mean **1251.015842** is greater than std **144.242011** so ths data is strong and stable.
# -In studentid **1001** is the minimum value and **1500** is the maximum value.
# -studentid feature have 25% of data lies below this value **1127**.
# -studentid have 50% of data lies below this value **1251**.
# -studentid have 75% of data lies below this value **1376**.

# %% [markdown]
# -Total_Sessions
# -totalsessions have **505** values.
# -totalsessions mean **120** is greater than std **0** so this data is strong and stable.
# -totalsessions **120** is the minimum value and **120** is the maximum value.
# -totalsessions have 25% of data lies below this value **120**.
# -totalsessions have 50% of data lies below this value **120**.
# -totalsessions have 75% of data lies below this value **120**.

# %% [markdown]
# -Sessions_Attended
# -sessionsattended have 505 values.
# -sessionattended mean **88.102970** is greater than std **17.087232** so this data is strong and stable.
# -sessionattended **60** is the minimum value and **119** is the maximum value.
# -sessionattended have 25% of data lies below this value **73**.
# -sessionattended have 50% of data lies below this value **88**.
# -sessionattended have 75% of data lies below this value **103**.

# %% [markdown]
# -Avg_Quiz_Score
# -avgquizscore have 505 values.
# -avgquizscore feature have mean **69.601980** is greater than std **17.137226** so this data is strong and stable.
# -avgquizscore **40** is the minimum value and **99** is the maximum value.
# -avgquizscore have 25% of data lies below this value **56**.
# -avgquizscore have 50% of data lies below this value **69**.
# -avgquizscore have 75% of data lies below this value **84**.

# %% [markdown]
# -Assignment_Score
# -assignmentscore have 505 values.
# -assignmentscore feature have mean **71.984158** is greater than std **15.777337** so this data is strong and stable.
# -assignmentscore **45** is the minimum value and **99** is the maximum value.
# -assignmentscore have 25% of data lies below this value **58**.
# -assignmentscore have 50% of data lies below this value **72**.
# -assignmentscore have 75% of data lies below this value **86**.

# %% [markdown]
# -Project_Score
# -projectscore have 505 values.
# -projectscore feature have mean **75.287129** is greater than std **14.678794** so this data is strong and stable.
# -projectscore **50** is the minimum value and **99** is the maximum value.
# -projectscore have 25% of data lies below this value **62**.
# -projectscore have 50% of data lies below this value **76**.
# -projectscore have 75% of data lies below this value **88**.

# %% [markdown]
# -Final_Rating
# -finalrating have 477 values.39 values are missing.
# -finalrating feature have mean **3.535220** is greater than std **0.862365** so this data is strong and stable.
# -finalrating **2** is the minimum value and **5** is the maximum value
# -finalrating have 25% of data lies below this value **2.800000**.
# -finalrating have 50% of data lies below this value **3.600000**.
# -finalrating have 75% of data lies below this value **4.300000**.

# %% [markdown]
# -Learning_Hours
# -learninghours have 505 values.
# -learninghours feature have mean **22.128713** is greater than std **9.924180** so this data is strong and stable.
# -learninghours **5** is the minimum value and **39** is the maximum value.
# -learninghours have 25% of data lies below this value **12**.
# -learninghours have 50% of data lies below this value **23**.
# -learninghours have 75% of data lies below this value **31**.

# %% [markdown]
# -Feedback_Score
# -feedbackscore have 505 values.
# -feedbackscore feature have mean **7.041584** is greater than std **1.370122** so this data is strong and stable.
# -feedbackscore **5** is the minimum value and **9** is the maximum value.
# -feedbackscore have 25% of data lies below this value **6**.
# -feedbackscore have 50% of data lies below this value **7**.
# -feedbackscore have 75% of data lies below this value **8**.

# %% [markdown]
# -Attendance_Pct
# -attendancepct have 505 values.
# -attendancepct feature have mean **73.419149** is greater than std **14.239418* so this data is strong and stable.
# -attendancepct **50** is the minimum value and **99** is the maximum value.
# -attendancepct have 25% of data lies below this value **60.830000**.
# -attendancepct have 50% of data lies below this value **73.330000**.
# -attendancepct have 75% of data lies below this value **85.830000**.

# %% [markdown]
# -Salary_Offered
# -salaryoffered have 3.360000e+05 values.
# -salaryoffered feature have mean **7.701324e+05** is greater than std **2.656396e+05** so this data is strong and stable.
# -salaryoffered **3.005150e+05** is the minimum value and **1.199092e+06**is the maximum value.
# -salaryoffered have 25% of data lies below this value **5.442040e+05**.
# -salaryoffered have 50% of data lies below this value **7.788115e+05**.
# -salaryoffered have 75% of data lies below this value **1.1003022e+06**.

# %% [markdown]
# Total_Score
# -totalscore have 505 values.
# -totalscore feature have mean **216.873267** is greater than std **27.491264** so this data is strong and stable.
# -totalscore **140** is the minimum value and **292** is the maximum value.
# -totalscore have 25% of data lies below this value **198**.
# -totalscore have 50% of data lies below this value **217**.
# -totalscore have 75% of data lies below this value **235**.

# %% [markdown]
# # 7.Identify columns that contain missing values

# %%
df.isna().sum()
# Out:
# student_id             0
# student_name           0
# gender                 0
# city                   0
# enrollment_date        0
# course                 0
# batch_type             0
# total_sessions         0
# sessions_attended      0
# avg_quiz_score         0
# assignment_score       0
# project_score          0
# final_rating          28
# learning_hours         0
# placement_status       0
# feedback_score         0
# attendance_pct         0
# salary_offered       169
# dtype: int64

# %% [markdown]
# # 8.Count the number of missing values in each column.

# %%
df.isna().sum()
# Out:
# student_id             0
# student_name           0
# gender                 0
# city                   0
# enrollment_date        0
# course                 0
# batch_type             0
# total_sessions         0
# sessions_attended      0
# avg_quiz_score         0
# assignment_score       0
# project_score          0
# final_rating          28
# learning_hours         0
# placement_status       0
# feedback_score         0
# attendance_pct         0
# salary_offered       169
# dtype: int64

# %% [markdown]
# # 9.Calculate the percentage of missing values in the final_rating column.

# %% [markdown]
# # 10.Fill missing values in the final_rating column using the mean.

# %%
df["final_rating"].fillna(df["final_rating"].mean(), inplace=True)
# Out:
# C:\Users\Neha\AppData\Local\Temp\ipykernel_7872\4148491563.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["final_rating"].fillna(df["final_rating"].mean(), inplace=True)

# %% [markdown]
# # 11.Verify that missing values in final_string are handled.

# %% [markdown]
# # 12.Check whether duplicate records exist in the dataset.

# %%
df.duplicated().sum()
# Out:
# np.int64(5)

# %% [markdown]
# # 13.Count the total number of duplicate rows.

# %%
df.duplicated().sum()
# Out:
# np.int64(5)

# %% [markdown]
# # 14.Display all duplicate records.

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 500     True
# 501     True
# 502     True
# 503     True
# 504     True
# Length: 505, dtype: bool

# %% [markdown]
# # 15.Remove duplicate records from the dataset.

# %% [markdown]
# # 16.Verify the dataset size after removing duplicates.

# %% [markdown]
# # 17.Find the number of unique values in the city column.

# %%
df["city"].nunique()
# Out:
# 6

# %% [markdown]
# # 18.Find the number of unique values in the course column.

# %%
df["course"].nunique()
# Out:
# 4

# %% [markdown]
# # 19.Display all unique cities present in the dataset.

# %%
df["city"].unique()
# Out:
# array(['Hyderabad', 'Pune', 'Delhi', 'Mumbai', 'Chennai', 'Bangalore'],
#       dtype=object)

# %% [markdown]
# # 20.Count the number of students in each city.

# %%
df["city"].value_counts()
# Out:
# city
# Hyderabad    100
# Mumbai        95
# Pune          87
# Bangalore     82
# Chennai       73
# Delhi         68
# Name: count, dtype: int64

# %% [markdown]
# # 21.Count the number of students enrolled in each course.

# %%
df["course"].value_counts()
# Out:
# course
# Data Analytics    143
# Data Science      128
# AI & ML           126
# Generative AI     108
# Name: count, dtype: int64

# %% [markdown]
# # 22.Identify the course with the highest student enrollment.

# %% [markdown]
# # 23.Count the number of students who are placed and not placed.

# %%
df[df["placement_status"]=="Placed"].value_counts()
# Out:
# student_id  student_name  gender  city       enrollment_date  course          batch_type  total_sessions  sessions_attended  avg_quiz_score  assignment_score  project_score  final_rating  learning_hours  placement_status  feedback_score  attendance_pct  salary_offered
# 1210        Student_210   Male    Bangalore  2024-04-04       AI & ML         Weekday     120             75                 40              84                77             2.4           19              Placed            5               62.50           750043.0          2
# 1178        Student_178   Male    Delhi      2024-01-20       Generative AI   Weekday     120             80                 97              92                66             4.7           33              Placed            5               66.67           890611.0          2
# ...

# %% [markdown]
# # 24.Filter students whose attendance percentage is greater than 80.

# %%
df[df["attendance_pct"]>80]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 0          1001    Student_1    Male  Hyderabad      2024-11-25
# 1          1002    Student_2  Female  Hyderabad      2024-09-29
# 4          1005    Student_5    Male     Mumbai      2024-02-03
# 6          1007    Student_7    Male     Mumbai      2024-02-22
# 7          1008    Student_8    Male    Chennai      2024-07-23
# ..          ...          ...     ...        ...             ...
# 475        1476  Student_476  Female    Chennai      2024-02-05
# 477        1478  Student_478  Female     Mumbai      2024-07-06
# 481        1482  Student_482  Female     Mumbai      2024-07-15
# 488        1489  Student_489    Male    Chennai      2024-10-19
# 504        1397  Student_397  Female     Mumbai      2024-05-27
#
#              course batch_type  total_sessions  sessions_attended  \
# 0     Generative AI    Weekday             120                108
# ...

# %% [markdown]
# # 25.Filter students who attended fewer than 70 sessions.

# %%
df[df["total_sessions"]>70]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 0          1001    Student_1    Male  Hyderabad      2024-11-25
# 1          1002    Student_2  Female  Hyderabad      2024-09-29
# 2          1003    Student_3    Male       Pune      2024-12-05
# 3          1004    Student_4    Male      Delhi      2024-03-09
# 4          1005    Student_5    Male     Mumbai      2024-02-03
# ..          ...          ...     ...        ...             ...
# 500        1452  Student_452  Female     Mumbai      2024-03-07
# 501        1276  Student_276  Female  Hyderabad      2024-10-15
# 502        1210  Student_210    Male  Bangalore      2024-04-04
# 503        1178  Student_178    Male      Delhi      2024-01-20
# 504        1397  Student_397  Female     Mumbai      2024-05-27
#
#             course batch_type  total_sessions  sessions_attended  \
# 0    Generative AI    Weekday             120                108
# ...

# %% [markdown]
# # 26.Filter students with an average quiz score above 85.

# %%
df[df["avg_quiz_score"]>85]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 6          1007    Student_7    Male     Mumbai      2024-02-22
# 14         1015   Student_15  Female      Delhi      2024-05-30
# 16         1017   Student_17  Female     Mumbai      2024-12-01
# 23         1024   Student_24  Female  Hyderabad      2024-12-17
# 33         1034   Student_34  Female  Bangalore      2024-04-01
# ..          ...          ...     ...        ...             ...
# 495        1496  Student_496    Male  Hyderabad      2024-12-29
# 496        1497  Student_497    Male  Hyderabad      2024-10-06
# 497        1498  Student_498  Female  Bangalore      2024-03-21
# 501        1276  Student_276  Female  Hyderabad      2024-10-15
# 503        1178  Student_178    Male      Delhi      2024-01-20
#
#              course batch_type  total_sessions  sessions_attended  \
# 6    Data Analytics    Weekend             120                112
# ...

# %% [markdown]
# # 27.Filter students enrolled in the Data Science course.

# %%
df[df["course"]=="Data Science"]
# Out:
#      student_id student_name  gender       city enrollment_date        course  \
# 2          1003    Student_3    Male       Pune      2024-12-05  Data Science
# 7          1008    Student_8    Male    Chennai      2024-07-23  Data Science
# 10         1011   Student_11    Male    Chennai      2024-02-12  Data Science
# 13         1014   Student_14    Male     Mumbai      2024-09-05  Data Science
# 18         1019   Student_19  Female       Pune      2024-01-08  Data Science
# ..          ...          ...     ...        ...             ...           ...
# 487        1488  Student_488  Female       Pune      2024-09-17  Data Science
# 489        1490  Student_490    Male       Pune      2024-09-12  Data Science
# 490        1491  Student_491  Female  Bangalore      2024-08-09  Data Science
# 495        1496  Student_496    Male  Hyderabad      2024-12-29  Data Science
# 498        1499  Student_499    Male     Mumbai      2024-07-20  Data Science
#
# ...

# %% [markdown]
# # 28.Filter students who are not placed and attended more than 75 sessions.

# %%
df[(df["placement_status"]=="Not Placed") & (df["sessions_attended"]>75)]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 1          1002    Student_2  Female  Hyderabad      2024-09-29
# 9          1010   Student_10  Female      Delhi      2024-08-22
# 10         1011   Student_11    Male    Chennai      2024-02-12
# 15         1016   Student_16    Male     Mumbai      2024-07-01
# 16         1017   Student_17  Female     Mumbai      2024-12-01
# ..          ...          ...     ...        ...             ...
# 469        1470  Student_470  Female  Hyderabad      2024-09-19
# 473        1474  Student_474  Female      Delhi      2024-05-26
# 480        1481  Student_481  Female     Mumbai      2024-10-29
# 488        1489  Student_489    Male    Chennai      2024-10-19
# 501        1276  Student_276  Female  Hyderabad      2024-10-15
#
#              course batch_type  total_sessions  sessions_attended  \
# 1           AI & ML    Weekday             120                110
# ...

# %% [markdown]
# # 29.Filter students belonging to Pune,Banglore,or Hyderabad.

# %%
df[df["city"].isin(["Pune", "Banglore","Hyderabad"])]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 0          1001    Student_1    Male  Hyderabad      2024-11-25
# 1          1002    Student_2  Female  Hyderabad      2024-09-29
# 2          1003    Student_3    Male       Pune      2024-12-05
# 5          1006    Student_6  Female       Pune      2024-09-18
# 18         1019   Student_19  Female       Pune      2024-01-08
# ..          ...          ...     ...        ...             ...
# 494        1495  Student_495    Male       Pune      2024-12-07
# 495        1496  Student_496    Male  Hyderabad      2024-12-29
# 496        1497  Student_497    Male  Hyderabad      2024-10-06
# 499        1500  Student_500  Female       Pune      2024-06-06
# 501        1276  Student_276  Female  Hyderabad      2024-10-15
#
#             course batch_type  total_sessions  sessions_attended  \
# 0    Generative AI    Weekday             120                108
# ...

# %% [markdown]
# # 30.Filter students enrolled in Ai & Ml or Generative AI courses.

# %%
df[df["course"].isin(["AI & ML", "Generative AI"])]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 0          1001    Student_1    Male  Hyderabad      2024-11-25
# 1          1002    Student_2  Female  Hyderabad      2024-09-29
# 3          1004    Student_4    Male      Delhi      2024-03-09
# 4          1005    Student_5    Male     Mumbai      2024-02-03
# 5          1006    Student_6  Female       Pune      2024-09-18
# ..          ...          ...     ...        ...             ...
# 500        1452  Student_452  Female     Mumbai      2024-03-07
# 501        1276  Student_276  Female  Hyderabad      2024-10-15
# 502        1210  Student_210    Male  Bangalore      2024-04-04
# 503        1178  Student_178    Male      Delhi      2024-01-20
# 504        1397  Student_397  Female     Mumbai      2024-05-27
#
#             course batch_type  total_sessions  sessions_attended  \
# 0    Generative AI    Weekday             120                108
# ...

# %% [markdown]
# # 31. Filter students whose average quiz score lies between 60 and 80.

# %%
df[df["avg_quiz_score"].between(60,80)]
# Out:
#      student_id student_name  gender     city enrollment_date          course  \
# 3          1004    Student_4    Male    Delhi      2024-03-09         AI & ML
# 5          1006    Student_6  Female     Pune      2024-09-18   Generative AI
# 7          1008    Student_8    Male  Chennai      2024-07-23    Data Science
# 8          1009    Student_9    Male   Mumbai      2024-05-05         AI & ML
# 9          1010   Student_10  Female    Delhi      2024-08-22  Data Analytics
# ..          ...          ...     ...      ...             ...             ...
# 489        1490  Student_490    Male     Pune      2024-09-12    Data Science
# 493        1494  Student_494  Female    Delhi      2024-12-20   Generative AI
# 494        1495  Student_495    Male     Pune      2024-12-07         AI & ML
# 498        1499  Student_499    Male   Mumbai      2024-07-20    Data Science
# 504        1397  Student_397  Female   Mumbai      2024-05-27   Generative AI
#
# ...

# %% [markdown]
# # 32.Filter students whose assignment score lies between 70 and 90.

# %%
df[df["assignment_score"].between(70,90)]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 2          1003    Student_3    Male       Pune      2024-12-05
# 6          1007    Student_7    Male     Mumbai      2024-02-22
# 7          1008    Student_8    Male    Chennai      2024-07-23
# 14         1015   Student_15  Female      Delhi      2024-05-30
# 20         1021   Student_21  Female       Pune      2024-07-02
# ..          ...          ...     ...        ...             ...
# 499        1500  Student_500  Female       Pune      2024-06-06
# 500        1452  Student_452  Female     Mumbai      2024-03-07
# 501        1276  Student_276  Female  Hyderabad      2024-10-15
# 502        1210  Student_210    Male  Bangalore      2024-04-04
# 504        1397  Student_397  Female     Mumbai      2024-05-27
#
#              course batch_type  total_sessions  sessions_attended  \
# 2      Data Science    Weekday             120                 73
# ...

# %% [markdown]
# # 33.Filter students whose learing hours lie between 10 and 25.

# %%
df[df["learning_hours"].between(10,25)]
# Out:
#      student_id student_name  gender       city enrollment_date  \
# 4          1005    Student_5    Male     Mumbai      2024-02-03
# 7          1008    Student_8    Male    Chennai      2024-07-23
# 8          1009    Student_9    Male     Mumbai      2024-05-05
# 10         1011   Student_11    Male    Chennai      2024-02-12
# 18         1019   Student_19  Female       Pune      2024-01-08
# ..          ...          ...     ...        ...             ...
# 499        1500  Student_500  Female       Pune      2024-06-06
# 500        1452  Student_452  Female     Mumbai      2024-03-07
# 501        1276  Student_276  Female  Hyderabad      2024-10-15
# 502        1210  Student_210    Male  Bangalore      2024-04-04
# 504        1397  Student_397  Female     Mumbai      2024-05-27
#
#             course batch_type  total_sessions  sessions_attended  \
# 4    Generative AI    Weekday             120                101
# ...

# %% [markdown]
# # 34.Create a new column total_score as the sum of quiz ,assignment,and project scores.

# %%
df["total_score"]=df["avg_quiz_score"]+df["assignment_score"]+df["project_score"]
print(df["total_score"])
# Out:
# 0      221
# 1      233
# 2      194
# 3      236
# 4      146
#       ...
# 500    226
# 501    264
# 502    201
# 503    255
# 504    215
# Name: total_score, Length: 505, dtype: int64

# %%
df.head()
# Out:
#    student_id student_name  gender       city enrollment_date         course  \
# 0        1001    Student_1    Male  Hyderabad      2024-11-25  Generative AI
# 1        1002    Student_2  Female  Hyderabad      2024-09-29        AI & ML
# 2        1003    Student_3    Male       Pune      2024-12-05   Data Science
# 3        1004    Student_4    Male      Delhi      2024-03-09        AI & ML
# 4        1005    Student_5    Male     Mumbai      2024-02-03  Generative AI
#
#   batch_type  total_sessions  sessions_attended  avg_quiz_score  \
# 0    Weekday             120                108              59
# 1    Weekday             120                110              57
# 2    Weekday             120                 73              49
# 3    Weekend             120                 71              64
# 4    Weekday             120                101              41
#
#    assignment_score  project_score  final_rating  learning_hours  \
# ...

# %% [markdown]
# # 35.Create a new column attendance_flag based on attendance percentage.

# %%
def percentage(x):
    if x>75:
        return "Good"
    else:
        return "Not Good"
df["attendance_flag"]=df["attendance_pct"].apply(percentage)

# %%
df.head()
# Out:
#    student_id student_name  gender       city enrollment_date         course  \
# 0        1001    Student_1    Male  Hyderabad      2024-11-25  Generative AI
# 1        1002    Student_2  Female  Hyderabad      2024-09-29        AI & ML
# 2        1003    Student_3    Male       Pune      2024-12-05   Data Science
# 3        1004    Student_4    Male      Delhi      2024-03-09        AI & ML
# 4        1005    Student_5    Male     Mumbai      2024-02-03  Generative AI
#
#   batch_type  total_sessions  sessions_attended  avg_quiz_score  \
# 0    Weekday             120                108              59
# 1    Weekday             120                110              57
# 2    Weekday             120                 73              49
# 3    Weekend             120                 71              64
# 4    Weekday             120                101              41
#
#    assignment_score  project_score  final_rating  learning_hours  \
# ...

# %% [markdown]
# # 36.Create a new column learning_intensity based on learing hours.

# %%
def learning_label(x):
    if x>20:
        return "High"
    elif x>=10:
        return "Medium"
    else:
        return "Low"
df["learning_intensity"]=df["learning_hours"].apply(learning_label)

# %%
df.head()
# Out:
#    student_id student_name  gender       city enrollment_date         course  \
# 0        1001    Student_1    Male  Hyderabad      2024-11-25  Generative AI
# 1        1002    Student_2  Female  Hyderabad      2024-09-29        AI & ML
# 2        1003    Student_3    Male       Pune      2024-12-05   Data Science
# 3        1004    Student_4    Male      Delhi      2024-03-09        AI & ML
# 4        1005    Student_5    Male     Mumbai      2024-02-03  Generative AI
#
#   batch_type  total_sessions  sessions_attended  avg_quiz_score  ...  \
# 0    Weekday             120                108              59  ...
# 1    Weekday             120                110              57  ...
# 2    Weekday             120                 73              49  ...
# 3    Weekend             120                 71              64  ...
# 4    Weekday             120                101              41  ...
#
#    project_score  final_rating  learning_hours  placement_status  \
# ...

# %% [markdown]
# # 37.Classify students based on total_score using apply().

# %%
def classify(x):
    if x >= 150:
        return 'First Class'
    elif x >= 100:
        return 'Pass'
    else:
        return 'Fail'
df["result"]=df["total_score"].apply(classify)

# %%
df.head()
# Out:
#    student_id student_name  gender       city enrollment_date         course  \
# 0        1001    Student_1    Male  Hyderabad      2024-11-25  Generative AI
# 1        1002    Student_2  Female  Hyderabad      2024-09-29        AI & ML
# 2        1003    Student_3    Male       Pune      2024-12-05   Data Science
# 3        1004    Student_4    Male      Delhi      2024-03-09        AI & ML
# 4        1005    Student_5    Male     Mumbai      2024-02-03  Generative AI
#
#   batch_type  total_sessions  sessions_attended  avg_quiz_score  ...  \
# 0    Weekday             120                108              59  ...
# 1    Weekday             120                110              57  ...
# 2    Weekday             120                 73              49  ...
# 3    Weekend             120                 71              64  ...
# 4    Weekday             120                101              41  ...
#
#    final_rating  learning_hours  placement_status  feedback_score  \
# ...

# %% [markdown]
# # 38.Create a placement eligibility column using apply().

# %%
def placement_eligibility(x):
    if x >= 150:
        return 'Eligible'
    else:
        return 'Not Eligible'
df["placement_eligibility"]=df["total_score"].apply(placement_eligibility)

# %%
df.head()
# Out:
#    student_id student_name  gender       city enrollment_date         course  \
# 0        1001    Student_1    Male  Hyderabad      2024-11-25  Generative AI
# 1        1002    Student_2  Female  Hyderabad      2024-09-29        AI & ML
# 2        1003    Student_3    Male       Pune      2024-12-05   Data Science
# 3        1004    Student_4    Male      Delhi      2024-03-09        AI & ML
# 4        1005    Student_5    Male     Mumbai      2024-02-03  Generative AI
#
#   batch_type  total_sessions  sessions_attended  avg_quiz_score  ...  \
# 0    Weekday             120                108              59  ...
# 1    Weekday             120                110              57  ...
# 2    Weekday             120                 73              49  ...
# 3    Weekend             120                 71              64  ...
# 4    Weekday             120                101              41  ...
#
#    learning_hours  placement_status  feedback_score  attendance_pct  \
# ...

# %% [markdown]
# # 39.Map placement_status values to numerical values.

# %%
numerical_values={
    "Placed":"01",
    "Not Placed":"02"
}
df["numerical"]=df["placement_status"].map(numerical_values)

# %%
df.head()
# Out:
#    student_id student_name  gender       city enrollment_date         course  \
# 0        1001    Student_1    Male  Hyderabad      2024-11-25  Generative AI
# 1        1002    Student_2  Female  Hyderabad      2024-09-29        AI & ML
# 2        1003    Student_3    Male       Pune      2024-12-05   Data Science
# 3        1004    Student_4    Male      Delhi      2024-03-09        AI & ML
# 4        1005    Student_5    Male     Mumbai      2024-02-03  Generative AI
#
#   batch_type  total_sessions  sessions_attended  avg_quiz_score  ...  \
# 0    Weekday             120                108              59  ...
# 1    Weekday             120                110              57  ...
# 2    Weekday             120                 73              49  ...
# 3    Weekend             120                 71              64  ...
# 4    Weekday             120                101              41  ...
#
#    placement_status  feedback_score  attendance_pct  salary_offered  \
# ...

# %% [markdown]
# # 40.Map batch_type values to abbreviated codes.

# %%
abbreviated_codes={
    "Weekday":"day",
    "Weekend":"end"
}
df["abbreviated"]=df["batch_type"].map(abbreviated_codes)

# %%
df.head()
# Out:
#    student_id student_name  gender       city enrollment_date         course  \
# 0        1001    Student_1    Male  Hyderabad      2024-11-25  Generative AI
# 1        1002    Student_2  Female  Hyderabad      2024-09-29        AI & ML
# 2        1003    Student_3    Male       Pune      2024-12-05   Data Science
# 3        1004    Student_4    Male      Delhi      2024-03-09        AI & ML
# 4        1005    Student_5    Male     Mumbai      2024-02-03  Generative AI
#
#   batch_type  total_sessions  sessions_attended  avg_quiz_score  ...  \
# 0    Weekday             120                108              59  ...
# 1    Weekday             120                110              57  ...
# 2    Weekday             120                 73              49  ...
# 3    Weekend             120                 71              64  ...
# 4    Weekday             120                101              41  ...
#
#    attendance_pct  salary_offered  total_score  attendance_flag  \
# ...

# %% [markdown]
# # 41.Map gender values to single letter codes.

# %%
letter_codes={
    "Male":"M",
    "Female":"F"
}
df["gender_values"]=df["gender"].map(letter_codes)

# %%
df.head()
# Out:
#    student_id student_name  gender       city enrollment_date         course  \
# 0        1001    Student_1    Male  Hyderabad      2024-11-25  Generative AI
# 1        1002    Student_2  Female  Hyderabad      2024-09-29        AI & ML
# 2        1003    Student_3    Male       Pune      2024-12-05   Data Science
# 3        1004    Student_4    Male      Delhi      2024-03-09        AI & ML
# 4        1005    Student_5    Male     Mumbai      2024-02-03  Generative AI
#
#   batch_type  total_sessions  sessions_attended  avg_quiz_score  ...  \
# 0    Weekday             120                108              59  ...
# 1    Weekday             120                110              57  ...
# 2    Weekday             120                 73              49  ...
# 3    Weekend             120                 71              64  ...
# 4    Weekday             120                101              41  ...
#
#    attendance_pct  salary_offered  total_score  attendance_flag  \
# ...

# %% [markdown]
# # 42.Count students under each learning_intensity category.

# %%
df["learning_intensity"].value_counts()
# Out:
# learning_intensity
# High      281
# Medium    152
# Low        72
# Name: count, dtype: int64

# %% [markdown]
# # 43.Calculate the percentage of placement-eligible students.

# %% [markdown]
# # 44.Identify the city with the highest number of placed students.

# %%
df["city"]=="Placed"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 500    False
# 501    False
# 502    False
# 503    False
# 504    False
# Name: city, Length: 505, dtype: bool

# %% [markdown]
# # 45.Compare average total_score for placed and not placed students.

# %% [markdown]
# # 46.Identify the top 5 students on total_score.

# %%
df["total_score"].head()
# Out:
# 0    221
# 1    233
# 2    194
# 3    236
# 4    146
# Name: total_score, dtype: int64
